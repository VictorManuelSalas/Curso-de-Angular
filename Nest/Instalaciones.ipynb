# %% [markdown]
# # Intlaciónes
#
#     1.- Node laster version
#     2.- Visual Extensions:
#         2.1 - Material icons
#         2.2 - thunder client
#     3.- Navegador Extencion:
#         3.1 - Json Viewer

# %% [markdown]
# ## Como instalar Nest JS
# En la terminal ejecutamos el comando
# `npm install -g @nestjs/cli` ya cuando termine puedes generar un nuevo proyecto.
#
# ### Listado de comandos útiles de NestJS
#
#     "Obtener versión": "nest --version",
#     "Crear un nuevo proyecto": "nest new nombre-proyecto",
#     "Generar un módulo": "nest generate module nombre-modulo",
#     "Generar un controlador": "nest generate controller nombre-controlador",
#     "Generar un servicio": "nest generate service nombre-servicio",
#     "Generar un recurso completo": "nest generate resource nombre-recurso",
#     "Iniciar servidor en desarrollo": "npm run start:dev",
#     "Compilar proyecto": "npm run build",
#     "Ejecutar servidor en producción": "npm run start:prod",
#     "Ejecutar tests": "npm run test",
#     "Ejecutar tests con cobertura": "npm run test:cov",
#     "Listar todos los comandos disponibles": "nest --help"

# %% [markdown]
# ### Crear proyecto

# %% [markdown]
#     1.- Usa el comando 'para crear el proyecto: `nest new Proyecto`
#     2.- Usa el coamndo para crear un controller :` nest g co name`
#     3.- Usa erl comando para crear un servicio:` nest g s name`
#     4.- Usa el comando para crear un modulo: `nest g mo name`
#     5.- Para evitar que los comandos generate te omitan el testing file usa el comando: `--no-spect`
#
#
# ## Validaciones En Nest
# Para validaciones se usan tanto interfaces de typescript como Validaciones nativas de nest
#
# Para usar las validaciones nativas es instalar :  ` npm i --save class-validator class-transformer`
